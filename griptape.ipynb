# %%
# !pip install griptape
# Out:
# Collecting griptape
#   Downloading griptape-0.22.3-py3-none-any.whl.metadata (15 kB)
# Collecting PyPDF2>=3 (from griptape)
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: attrs>=22 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from griptape) (23.2.0)
# Requirement already satisfied: cryptography<42.0.0,>=41.0.4 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from griptape) (41.0.7)
# Collecting dateparser<2.0.0,>=1.1.8 (from griptape)
#   Downloading dateparser-1.2.0-py2.py3-none-any.whl.metadata (28 kB)
# Collecting docker<7.0.0,>=6.1.3 (from griptape)
#   Downloading docker-6.1.3-py3-none-any.whl.metadata (3.5 kB)
# Collecting jinja2>=3.1 (from griptape)
#   Downloading Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting jsonschema>=4 (from griptape)
#   Downloading jsonschema-4.21.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting lxml<5.0.0,>=4.9.3 (from griptape)
#   Downloading lxml-4.9.4-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Collecting mail-parser<4.0.0,>=3.15.0 (from griptape)
#   Downloading mail_parser-3.15.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: marshmallow>=3 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from griptape) (3.20.2)
# Collecting marshmallow-enum>=1.5 (from griptape)
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: numpy>=1 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from griptape) (1.26.3)
# Requirement already satisfied: openai<2.0.0,>=1.1.1 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from griptape) (1.8.0)
# Requirement already satisfied: pandas>=1.3 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from griptape) (2.2.0)
# Requirement already satisfied: pillow<11.0.0,>=10.1.0 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from griptape) (10.2.0)
# Requirement already satisfied: pyyaml>=6 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from griptape) (6.0.1)
# Requirement already satisfied: requests<3,>=2 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from griptape) (2.31.0)
# Collecting rich>=13 (from griptape)
#   Downloading rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting schema>=0.7 (from griptape)
#   Downloading schema-0.7.5-py2.py3-none-any.whl (17 kB)
# Collecting sqlalchemy<2.0,>=1.0 (from griptape)
#   Downloading SQLAlchemy-1.4.51-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting stringcase<2.0.0,>=1.2.0 (from griptape)
#   Downloading stringcase-1.2.0.tar.gz (3.0 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tenacity>=8.0 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from griptape) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from griptape) (0.5.2)
# Collecting trafilatura>=1.6 (from griptape)
#   Downloading trafilatura-1.7.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: cffi>=1.12 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from cryptography<42.0.0,>=41.0.4->griptape) (1.16.0)
# Requirement already satisfied: python-dateutil in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.1.8->griptape) (2.8.2)
# Requirement already satisfied: pytz in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.1.8->griptape) (2023.3.post1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.1.8->griptape) (2023.12.25)
# Collecting tzlocal (from dateparser<2.0.0,>=1.1.8->griptape)
#   Downloading tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: packaging>=14.0 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from docker<7.0.0,>=6.1.3->griptape) (23.2)
# Requirement already satisfied: urllib3>=1.26.0 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from docker<7.0.0,>=6.1.3->griptape) (2.1.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from docker<7.0.0,>=6.1.3->griptape) (1.7.0)
# Collecting MarkupSafe>=2.0 (from jinja2>=3.1->griptape)
#   Downloading MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=4->griptape)
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=4->griptape)
#   Downloading referencing-0.33.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=4->griptape)
#   Downloading rpds_py-0.17.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting simplejson>=3.17.0 (from mail-parser<4.0.0,>=3.15.0->griptape)
#   Downloading simplejson-3.19.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.1 kB)
# Requirement already satisfied: six>=1.14.0 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from mail-parser<4.0.0,>=3.15.0->griptape) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.1.1->griptape) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.1.1->griptape) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.1.1->griptape) (0.26.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.1.1->griptape) (2.5.3)
# Requirement already satisfied: sniffio in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.1.1->griptape) (1.3.0)
# Requirement already satisfied: tqdm>4 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.1.1->griptape) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.1.1->griptape) (4.9.0)
# Requirement already satisfied: tzdata>=2022.7 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from pandas>=1.3->griptape) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from requests<3,>=2->griptape) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from requests<3,>=2->griptape) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from requests<3,>=2->griptape) (2023.11.17)
# Collecting markdown-it-py>=2.2.0 (from rich>=13->griptape)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from rich>=13->griptape) (2.17.2)
# Collecting contextlib2>=0.5.5 (from schema>=0.7->griptape)
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from sqlalchemy<2.0,>=1.0->griptape) (3.0.3)
# Collecting courlan>=0.9.5 (from trafilatura>=1.6->griptape)
#   Downloading courlan-1.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting htmldate>=1.7.0 (from trafilatura>=1.6->griptape)
#   Downloading htmldate-1.7.0-py3-none-any.whl.metadata (11 kB)
# Collecting justext>=3.0.0 (from trafilatura>=1.6->griptape)
#   Downloading jusText-3.0.0-py2.py3-none-any.whl (837 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 837.8/837.8 kB 7.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pycparser in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from cffi>=1.12->cryptography<42.0.0,>=41.0.4->griptape) (2.21)
# Collecting langcodes>=3.3.0 (from courlan>=0.9.5->trafilatura>=1.6->griptape)
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 17.0 MB/s eta 0:00:00
# Collecting tld>=0.13 (from courlan>=0.9.5->trafilatura>=1.6->griptape)
#   Downloading tld-0.13-py2.py3-none-any.whl (263 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.8/263.8 kB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: httpcore==1.* in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.1.1->griptape) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.1.1->griptape) (0.14.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13->griptape)
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai<2.0.0,>=1.1.1->griptape) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /workspaces/ml-learning/.venv/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai<2.0.0,>=1.1.1->griptape) (2.14.6)
# Downloading griptape-0.22.3-py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.5/229.5 kB 17.5 MB/s eta 0:00:00
# Downloading dateparser-1.2.0-py2.py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 11.4 MB/s eta 0:00:00
# Downloading docker-6.1.3-py3-none-any.whl (148 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 8.6 MB/s eta 0:00:00
# Downloading Jinja2-3.1.3-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 kB 1.9 MB/s eta 0:00:00ta 0:00:01
# Downloading jsonschema-4.21.1-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 kB 17.5 MB/s eta 0:00:00
# Downloading lxml-4.9.4-cp311-cp311-manylinux_2_28_x86_64.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 10.5 MB/s eta 0:00:0000:0100:01
# Downloading rich-13.7.0-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 29.2 MB/s eta 0:00:00
# Downloading SQLAlchemy-1.4.51-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 10.4 MB/s eta 0:00:00a 0:00:01
# Downloading trafilatura-1.7.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 12.7 MB/s eta 0:00:00a 0:00:01
# Downloading courlan-1.0.0-py3-none-any.whl (35 kB)
# Downloading htmldate-1.7.0-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 1.2 MB/s eta 0:00:00
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 14.0 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Downloading referencing-0.33.0-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.17.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 12.5 MB/s eta 0:00:00a 0:00:01
# Downloading simplejson-3.19.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.7/144.7 kB 8.3 MB/s eta 0:00:00
# Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Building wheels for collected packages: stringcase
#   Building wheel for stringcase (pyproject.toml) ... done
#   Created wheel for stringcase: filename=stringcase-1.2.0-py3-none-any.whl size=3569 sha256=d8593c163e599ae92ba6b48f5c8c71f97e1f96624766f8a1c3e8e453e6542b95
#   Stored in directory: /home/vscode/.cache/pip/wheels/b4/33/6d/d0820be98063da218c3206fbad2381cd2db3fbb1a0f0d254b5
# Successfully built stringcase
# Installing collected packages: stringcase, tzlocal, tld, sqlalchemy, simplejson, rpds-py, PyPDF2, mdurl, MarkupSafe, lxml, langcodes, contextlib2, schema, referencing, marshmallow-enum, markdown-it-py, mail-parser, justext, jinja2, docker, dateparser, courlan, rich, jsonschema-specifications, htmldate, trafilatura, jsonschema, griptape
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.25
#     Uninstalling SQLAlchemy-2.0.25:
#       Successfully uninstalled SQLAlchemy-2.0.25
# Successfully installed MarkupSafe-2.1.5 PyPDF2-3.0.1 contextlib2-21.6.0 courlan-1.0.0 dateparser-1.2.0 docker-6.1.3 griptape-0.22.3 htmldate-1.7.0 jinja2-3.1.3 jsonschema-4.21.1 jsonschema-specifications-2023.12.1 justext-3.0.0 langcodes-3.3.0 lxml-4.9.4 mail-parser-3.15.0 markdown-it-py-3.0.0 marshmallow-enum-1.5.1 mdurl-0.1.2 referencing-0.33.0 rich-13.7.0 rpds-py-0.17.1 schema-0.7.5 simplejson-3.19.2 sqlalchemy-1.4.51 stringcase-1.2.0 tld-0.13 trafilatura-1.7.0 tzlocal-5.2
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
import logging
import sys

logging.basicConfig(stream=sys.stdout, level=logging.INFO)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

from IPython.display import Markdown, display

from dotenv import load_dotenv

load_dotenv('/workspaces/ml-learning/.env', override=True)

import nest_asyncio
nest_asyncio.apply()

# %load_ext autoreload
# %autoreload 2

# %%
# Create a Griptape Agent and give it a WebScraper tool
# Use the Chat utility to chat with it.

from griptape.structures import Agent
from griptape.tools import WebScraper
from griptape.utils import Chat

# Create the agent and give it a WebScraper tool
agent = Agent( 
    tools=[ WebScraper(off_prompt=False) ]
)

# Chat with the agent
Chat(agent).start()
# Out:
# Thinking...
# [02/03/24 04:45:22] INFO     ToolkitTask 85c4c6c745074a3ba29d45bcdb16432f
#                              Input:
# INFO:root:gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [02/03/24 04:45:23] INFO     ToolkitTask 85c4c6c745074a3ba29d45bcdb16432f
#                              Output:
# Assistant:
# Thinking...
# [02/03/24 04:46:05] INFO     ToolkitTask 85c4c6c745074a3ba29d45bcdb16432f
#                              Input: Can you find benchmarks and comparisons for vector database
# INFO:root:gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [02/03/24 04:46:10] INFO     Subtask 5452a524cbcb44e6b823e4543c7f0395
#                              Thought: To find benchmarks and comparisons for vector databases, I will use the
#                              WebScraper action to load a web page with this information. I will start by searching
#                              for "vector database benchmarks and comparisons" on a search engine and then scrape
#                              the content of the most relevant page.
#
#                              Action:
#                              {
#                                "name": "WebScraper",
#                                "path": "get_content",
#                                "input": {
#                                  "values": {
#                                    "url":
#                              "https://www.google.com/search?q=vector+database+benchmarks+and+comparisons"
#                                  }
#                                }
#                              }
# [02/03/24 04:46:15] INFO     Subtask 5452a524cbcb44e6b823e4543c7f0395
#                              Response: Rankings Ranking positions based on each vector database's comprehensive QPS
#                              scores.
#                              Databases with different hardware resources
#                              QPS/RecallMedium OpenAI Low Filter
#                              1
#                              ZillizCloud-8cu-perf
#                              1583 / 0.984
#                              2
#                              Milvus-16c64g-hnsw
#                              599.421 / 0.996
#                              3
#                              QdrantCloud-4c16g-5node
#                              434.406 / 0.918
#                              4
#                              Pinecone-p2.x1-8node
#                              303.8 / 0.948
#                              Picking a vector database: a comparison and guide for 2023 ... The data behind the
#                              comparision comes from ANN Benchmarks, the docs and internal benchmarks of each ...
#                              People also ask
#                              Which vector DB is best?
#                              How do you evaluate a vector database?
#                              How do I choose a vector database?
#                              What is a benchmark in database?
#                              The first comparative benchmark and benchmarking framework for vector search engines
#                              and vector databases.
#                              Which Vector Database Should I Use? A Comparison Cheatsheet
#                              navidre.medium.com › which-vector-database-should-i-use-a-comparison-...
#                              29 July 2023 · Vector databases compared are: Weaviate, Pinecone, pgvector, Milvus,
#                              MongoDB, Qdrant, and Chroma. The benchmark data is from ANN Benchmarks.
#                              Evaluate Vector Database / Benchmarks? : r/mlops - Reddit
#                              www.reddit.com › mlops › comments › evaluate_vector_database_benchm...
#                              29 June 2023 · By far the most popular benchmark is ANN Benchmark. It evaluates both
#                              scientific libraries and vector databases. It can give you a starting ...
#                              I have prepared this comparison table to help me choose a vector database. I ... Some
#                              benchmarks: https://qdrant.tech/benchmarks/ · simonw 5 months ago | root ...
#                              zilliztech/VectorDBBench: A Benchmark Tool for VectorDB - GitHub
#                              github.com › zilliztech › VectorDBBench
#                              VectorDBBench aims to provide a more comprehensive, multi-faceted testing environment
#                              that accurately represents the complexity of vector databases. By moving ...
#                              15 Dec 2023 · This report contains comprehensive detail on our benchmark and an
#                              analysis of the results. We tested the critical dimensions of vector database ...
#                              Open-Source Vector Database Benchmarking - Blueteam AI
#                              marketing.fmops.ai › blog › vector-benchmarking
#                              17 Aug 2023 · Open-Source Vector Database Benchmarking ... We set out to test
#                              open-source databases to figure out differences in performance and potential cost.
#                              Please Use Streaming Workload to Benchmark Vector Databases
#                              towardsdatascience.com › please-use-streaming-workload-to-benchmark-ve...
#                              1 Dec 2023 · In this blog post, I deep dive into (4) above and show you a new insight
#                              I discovered using a streaming workload benchmark. Compare recall ...
# INFO:root:gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [02/03/24 04:46:19] INFO     Subtask aeb6920024d84d129c4e754258f3e6d1
#                              Thought: The response contains several links to articles and resources that might
#                              contain benchmarks and comparisons for vector databases. I will choose the most
#                              relevant link and use the WebScraper action to load its content.
#
#                              Action: {"name": "WebScraper", "path": "get_content", "input": {"values": {"url":
#                              "https://navidre.medium.com/which-vector-database-should-i-use-a-comparison-cheatsheet
#                              "}}}
#                     INFO     Subtask aeb6920024d84d129c4e754258f3e6d1
#                              Response: Open in app
#                              Sign up
#                              Sign in
#                              Write
#                              Sign up
#                              Sign in
#                              PAGE NOT FOUND
#                              404
#                              Out of nothing, something.
#                              You can find (just about) anything on Medium — apparently even a page that doesn’t
#                              exist. Maybe these stories about finding what you didn’t know you were looking for
#                              will take you somewhere new?
#                              Home
#                              How To Get Lost
#                              Paul Greenberg
#                              Feb 22, 2022
#                              ·
#                              11 min read
#                              Member-only
#                              How To Get Lost
#                              Paul Greenberg
#                              Feb 22, 2022
#                              ·
#                              11 min read
#                              Member-only
#                              Lost in Conversation
#                              Omar Merza
#                              in The Coffeelicious
#                              Sep 19, 2017
#                              ·
#                              5 min read
#                              Lost in Conversation
#                              Omar Merza
#                              in The Coffeelicious
#                              Sep 19, 2017
#                              ·
#                              5 min read
#                              The Lost Photographs of Penang
#                              Ted Anthony
#                              in Stuff Dot Life
#                              Sep 19, 2017
#                              ·
#                              10 min read
#                              Member-only
#                              The Lost Photographs of Penang
#                              Ted Anthony
#                              in Stuff Dot Life
#                              Sep 19, 2017
#                              ·
#                              10 min read
#                              Member-only
#                              To Anyone Who Has Lost Themselves
#                              Jamie Varon
#                              Jun 20, 2018
#                              ·
#                              6 min read
#                              To Anyone Who Has Lost Themselves
#                              Jamie Varon
#                              Jun 20, 2018
#                              ·
#                              6 min read
# INFO:root:gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [02/03/24 04:46:22] INFO     Subtask e71e254476154f71b7479fac3995ca4d
#                              Thought: The link to the Medium article is not working. I will try another link from
#                              the search results.
#                              Action: {"name": "WebScraper", "path": "get_content", "input": {"values": {"url":
#                              "https://github.com/zilliztech/VectorDBBench"}}}
# [02/03/24 04:46:23] INFO     Subtask e71e254476154f71b7479fac3995ca4d
#                              Response: We read every piece of feedback, and take your input very seriously.
#                              To see all available qualifiers, see our documentation.
#                              A Benchmark Tool for VectorDB
# INFO:root:gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [02/03/24 04:46:26] INFO     Subtask f22b8ef51e5941c3b21a121f222ded40
#                              Thought: The content from the GitHub page does not provide the needed information. I
#                              will try another link from the search results.
#                              Action: {"name": "WebScraper", "path": "get_content", "input": {"values": {"url":
#                              "https://marketing.fmops.ai/blog/vector-benchmarking"}}}
# INFO:urllib3.poolmanager:Redirecting https://marketing.fmops.ai/blog/vector-benchmarking -> https://marketing.fmops.ai/blog/vector-benchmarking/
# Redirecting https://marketing.fmops.ai/blog/vector-benchmarking -> https://marketing.fmops.ai/blog/vector-benchmarking/
#                     INFO     Subtask f22b8ef51e5941c3b21a121f222ded40
#                              Response: Overview
#                              - Added Redis and Chroma clients to open-source vector benchmarking project
#                              [VectorDBBench](https://github.com/zilliztech/VectorDBBench)
#                              - Ran local benchmark tests and found the following key takeaways:
#                              - If memory isn't an issue, Redis performs extremely well.
#                              - For ease of use, Chroma's API and setup are user friendly. Its load duration and
#                              recall were not the best performing but it is still practical for most cases and will
#                              likely perform better when running in-process.
#                              - PgVector has the tradeoff of perfect recall for a sacrifice in speed and
#                              performance. However, Redis-Flat outshines it in performance (but not memory usage).
#                              Intro
#                              The options for vector databases can be a little overwhelming. There’s open source
#                              options from widely deployed databases like
#                              [Redis](https://redis.io/docs/interact/search-and-query/search/vectors/) and Postgres
#                              (utilizing the [PgVector](https://github.com/pgvector/pgvector) library), newer open
#                              source projects like [Chroma](https://www.trychroma.com/), and also paid services like
#                              Pinecone, Zilliz, Milvus and Qdrant.
#                              Vector databases can run in-process or independent of the application using them,
#                              utilize either IVFFlat or HNSW to store the vectors, and store the data either
#                              in-memory, on disk, or a hybrid of the two. Some advantages and disdvantages to these
#                              differences:
#                              - An advantage to using an in-process database is improved performance, since the data
#                              is transferred within the same memory space and not across sockets.
#                              - A disadvantage to an in-process database is the inability to independently scale
#                              components (since it is using the same memory space as the application it runs in).
#                              - HNSW gives improved search performance over IVFFlat at the expense of build time,
#                              index size, and recall (search accuracy).
#                              - IVFFlat is slower to search than HNSW, uses less memory, builds faster, and has
#                              greater search accuracy than HNSW.
#                              - Redis and Postgres are widely deployed (and due to this have a potentially lower
#                              technical cost).
#                              - In memory storage is fast and costly, whereas on-disk is cheap and slower.
#                              We set out to test open-source databases to figure out differences in performance and
#                              potential cost. The ones we tested are listed here along with some of their key
#                              characteristics:
#                              - Redis operates completely in memory and has capability to use both HNSW and IVFFLat.
#                              It does not run in-process. Since it does not utilize disk, perfomance is high but so
#                              is the cost.
#                              - Chroma runs in-process or client-server and supports HNSW. It utilizes both memory
#                              and disk.
#                              - PgVector only supports IVFFlat at the time of this writing, it does not run in
#                              process, and it utilizes memory and disk.
#                              We wanted to test for performance, specifically queries per second, latency, and load
#                              duration.
#                              We wanted to know which open-source vector database should we use?
#                              We started by looking to see if somebody else had already done some testing that
#                              answered this question (because it’s really nice when somebody else has figured it out
#                              already).
#                              Two benchmarking test results were close to what we were looking for, but nothing fit
#                              our needs exactly.
#                              Jina Benchmarks
#                              The first relevant results are some
#                              [benchmarking](https://jina.ai/news/benchmark-vector-search-databases-with-one-million
#                              -data/) done by Jina that included Redis, SQLite, ElasticCloud and a few others. The
#                              tests used 128 dimension vectors but also seem reliable and well done.
#                              Their conclusion:
#                              If your data set is large but still fits in memory, go with Redis or AnnLite. If your
#                              dataset does not fit in memory, and you do not care much about the speed of nearest
#                              neighbor search, you can use SQLite as storage.
#                              Otherwise, Weaviate, Qdrant and Elasticsearch are good options.
#                              Based on this information we decided to leave SQLite out of the testing since speed is
#                              certainly a factor.
#                              Here’s a graphic overview of Jina’s tests. It’s qps plotted against the fraction of
#                              true nearest neighbors found, on average over all queries using a dataset of 1M 768
#                              dimensional vectors. Up and to the right is better.
#                              Jina's benchmarks did not include Postgres and Chroma, and they were missing a
#                              comparison of Redis's HNSW and IVFFlat settings, so we kept looking.
#                              Zilliztech Benchmarks
#                              The other notable benchmarking we found was an open source project called
#                              VectorDBBench which can be found
#                              [here](https://github.com/zilliztech/VectorDBBench) (referred to after this point as
#                              VDB).
#                              VDB measured a lot of the things that we wanted to measure when comparing databases.
#                              Here’s an example of their nice front end comparing queries per second:
#                              (Note PgVector using IVFFlat at the bottom).
#                              Here’s a quote from their
#                              [github](https://github.com/zilliztech/VectorDBBench) about their hardware used for
#                              testing:
#                              All standard benchmark results are generated by a client running on an 8 core, 32 GB
#                              host, which is located in the same region as the server being tested. The client host
#                              is equipped with an Intel(R) Xeon(R) Platinum 8375C CPU @ 2.90GHz processor. Also all
#                              the servers for the open-source systems tested in our benchmarks run on hosts with the
#                              same type of processor.
#                              VDB measures queries per second, latency and recall in the performance cases, as well
#                              as search filtering performance, capacity and queries per dollar.
#                              VDB has a bunch of different vector sets to use for testing but unfortunately as of
#                              the time of this writing it does not have a 1536 dimensional dataset (openAI
#                              embedding’s ada-002 vector size). We figured that we could get approximate results
#                              with their existing data set. (Update: VDB added a 1536 dimension dataset right before
#                              publication)
#                              Zilliz's tests were missing a few open source databases that we wanted tested (like
#                              Redis and Chroma) so we set out to add them.
#                              Databases Tested
#                              We added the following clients to VDB for testing
#                              Already built into VDB:
#                              - Pinecone
#                              - ZillizCloud
#                              - ElasticCloud
#                              - Weaviate
#                              - Milvus
#                              - Qdrant
#                              - PgVector
#                              We intended to test out SQLite using the
#                              [sqlite-vss](https://github.com/asg017/sqlite-vss) package but we decided Jina's
#                              [benchmark](https://jina.ai/news/benchmark-vector-search-databases-with-one-million-da
#                              ta/) (mentioned above) leads to the conclusion that SQLite’s vector storage and
#                              retrieval is pretty slow in comparison to other databases. VDB may add sqlite-vss in
#                              the future and its performance can be further evaluated.
#                              Testing Methodology
#                              The basic layout for our local testing was for our intern to create a docker container
#                              on their M1 16gb Mac that ran the database being tested, and use VDB locally to get
#                              approximate benchmarks for some of the free databases while the great folks at VDB
#                              incorporated our pull requests and ran tests on their standardized machine.
#                              We ran into some hardware limitations. The Mac air that was used for testing really
#                              struggled through some of these tests, but overall the goal was to produce some quick
#                              apples to apples comparisons of the following databases / libraries:
#                              - Redis-Flat
#                              - Redis-HNSW
#                              - Chroma
#                              - PgVector
#                              Tests
#                              After we created and added the clients for Redis and Chroma, we ran some preliminary
#                              tests using the built in 1M 768 dimension Cohere dataset. We ran into some time-out
#                              issues in these tests (discussed in "Issues Encountered During Benchmarking" section
#                              below).
#                              To resolve the issues in a way that could still allow the databases to be compared via
#                              VDB on our hardware, we shortened the data set size to 300k and ran some tests. These
#                              are the results:
#                              Some observations about these tests:
#                              - Chroma has the lowest recall and highest load duration
#                              - HNSW takes a lot longer to load than IVFFLat, but results in better search
#                              performance.
#                              - PgVector's latency is high
#                              Issues Encountered During Benchmarking
#                              When we ran initial tests on the 1M dataset, these are some of the issues we
#                              encountered:
#                              - Redis-Flat timed out during recall testing.
#                              - Chroma also timed out during recall testing.
#                              - Redis-HNSW took exponential time to build and timed out around half a million
#                              vectors during the load phase. Every 100,000 vectors that were added took twice as
#                              long as the previous 100,000. The load phase timeout in VDB is 2.5 hours.
#                              - Chroma running in client-server mode was hit and miss in terms of functionality. A
#                              lot of the time the database would unexpectedly terminate the connection while
#                              loading. The load time was also slow and would sometimes time out.
#                              Redis took a long time to build the HNSW index, despite tweaking the parameters down
#                              fairly low in some of the tests. This could definitely be a hardware limitation or
#                              operator error, as could all of the other issues. Here's a screenshot of the database
#                              load times:
#                              Conclusion
#                              Redis HNSW seems like a clear winner (on this hardware, with this setup, for this
#                              small size dataset). Redis runs in memory, and assuming that we had enough memory we
#                              could get these speeds in a full scale deployment. This confirms the results
#                              previously mentioned by Jina. Assuming memory isn't a problem, Redis is fast.
#                              As the maintainers of the VDB project run tests on their machines, comparisons for
#                              paid database services against open source options like Redis, Chroma and Postgres
#                              will be available.
# INFO:root:gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [02/03/24 04:46:35] INFO     ToolkitTask 85c4c6c745074a3ba29d45bcdb16432f
#                              Output: Here are some key takeaways from the benchmarking and comparison of vector
#                              databases:
#
#                              1. Redis: Operates completely in memory and has the capability to use both HNSW and
#                              IVFFLat. It does not run in-process. Since it does not utilize disk, performance is
#                              high but so is the cost.
#
#                              2. Chroma: Runs in-process or client-server and supports HNSW. It utilizes both memory
#                              and disk.
#
#                              3. PgVector: Only supports IVFFlat at the time of writing, it does not run in process,
#                              and it utilizes memory and disk.
#
#                              In terms of performance, Redis HNSW seems to be a clear winner assuming that memory
#                              isn't a problem. Redis is fast but runs in memory, which can be costly. Chroma has the
#                              lowest recall and highest load duration. PgVector's latency is high.
#
#                              Please note that these results are based on specific hardware and setup, and the
#                              performance may vary based on different factors. For a more comprehensive comparison,
#                              it's recommended to check out the original source
#                              [here](https://marketing.fmops.ai/blog/vector-benchmarking).
# Assistant: Here are some key takeaways from the benchmarking and comparison of vector databases:
#
# 1. Redis: Operates completely in memory and has the capability to use both HNSW and IVFFLat. It does not run in-process. Since it does not utilize disk, performance is high but so is the cost.
#
# 2. Chroma: Runs in-process or client-server and supports HNSW. It utilizes both memory and disk.
#
# 3. PgVector: Only supports IVFFlat at the time of writing, it does not run in process, and it utilizes memory and disk.
#
# In terms of performance, Redis HNSW seems to be a clear winner assuming that memory isn't a problem. Redis is fast but runs in memory, which can be costly. Chroma has the lowest recall and highest load duration. PgVector's latency is high.
#
# Please note that these results are based on specific hardware and setup, and the performance may vary based on different factors. For a more comprehensive comparison, it's recommended to check out the original source [here](https://marketing.fmops.ai/blog/vector-benchmarking).
# Thinking...
# [02/03/24 04:50:38] INFO     ToolkitTask 85c4c6c745074a3ba29d45bcdb16432f
#                              Input: Can you write a paragraph of introduction about vector databases using online
#                              sources. Please be specific. the audience is engineers wanting to understand vector
#                              databases
# INFO:root:gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [02/03/24 04:50:42] INFO     Subtask ba85e187f5c949f6bde256529caf7630
#                              Thought: I need to find a reliable source that provides a detailed introduction to
#                              vector databases. I will use the WebScraper action to load a webpage that contains
#                              this information.
#
#                              Action:
#                              {
#                                "name": "WebScraper",
#                                "path": "get_content",
#                                "input": {
#                                  "values": {
#                                    "url":
#                              "https://towardsdatascience.com/what-are-vector-databases-and-why-you-should-care-7d6b
#                              0a4e6b36"
#                                  }
#                                }
#                              }
# INFO:urllib3.poolmanager:Redirecting https://towardsdatascience.com/what-are-vector-databases-and-why-you-should-care-7d6b0a4e6b36 -> https://medium.com/m/global-identity-2?redirectUrl=https%3A%2F%2Ftowardsdatascience.com%2Fwhat-are-vector-databases-and-why-you-should-care-7d6b0a4e6b36
# Redirecting https://towardsdatascience.com/what-are-vector-databases-and-why-you-should-care-7d6b0a4e6b36 -> https://medium.com/m/global-identity-2?redirectUrl=https%3A%2F%2Ftowardsdatascience.com%2Fwhat-are-vector-databases-and-why-you-should-care-7d6b0a4e6b36
# INFO:urllib3.poolmanager:Redirecting https://medium.com/m/global-identity-2?redirectUrl=https%3A%2F%2Ftowardsdatascience.com%2Fwhat-are-vector-databases-and-why-you-should-care-7d6b0a4e6b36 -> https://towardsdatascience.com/what-are-vector-databases-and-why-you-should-care-7d6b0a4e6b36?gi=1f5bcfd5c5a2
# Redirecting https://medium.com/m/global-identity-2?redirectUrl=https%3A%2F%2Ftowardsdatascience.com%2Fwhat-are-vector-databases-and-why-you-should-care-7d6b0a4e6b36 -> https://towardsdatascience.com/what-are-vector-databases-and-why-you-should-care-7d6b0a4e6b36?gi=1f5bcfd5c5a2
# [02/03/24 04:50:43] INFO     Subtask ba85e187f5c949f6bde256529caf7630
#                              Response: Open in app
#                              Sign up
#                              Sign in
#                              Write
#                              Sign up
#                              Sign in
#                              PAGE NOT FOUND
#                              404
#                              Out of nothing, something.
#                              You can find (just about) anything on Medium — apparently even a page that doesn’t
#                              exist. Maybe these stories about finding what you didn’t know you were looking for
#                              will take you somewhere new?
#                              Home
#                              How To Get Lost
#                              Paul Greenberg
#                              Feb 22, 2022
#                              ·
#                              11 min read
#                              Member-only
#                              How To Get Lost
#                              Paul Greenberg
#                              Feb 22, 2022
# ...
#                              Marqo can be used with text and/or image data. Multimodal indexes seamlessly handle
#                              image-to-image, image-to-text and text-to-image search.
#                              Marqo supports weighted queries which can combine multiple text and image queries
#                              together. Negative weights can be added to query terms to push certain items out of
#                              your result set.
#                              Marqo supports score modifiers, numeric fields in your documents can be used to
#                              manipulate the score and influence the ranking of results.
#                              Additional context can be added to queries by providing vectors directly, this helps
#                              tailor results without the overhead of additional inference.
#                              Import open source models from Hugging Face, bring your own, or load private models
#                              from AWS S3 or Hugging Face using authentication.
#                              Parts of Marqo's API support bulk operations to improve throughput. These bulk
#                              operations enable use cases such as bulk changes to multiple indexes or coalescing of
#                              queries.
#                              Marqo is horizontally scalable and can be run at million document scale whilst
#                              maintaining lightning-fast search times.
#                              Marqo provides search highlighting functionality which allows you to transparently
#                              understand where and why a match occurred.
#                              Marqo offers a powerful query DSL (Domain Specific Language), which can be applied as
#                              a prefilter ahead of approximate k-NN search.
#                              Get involved with building the future of Marqo or access support from Marqo's vast
#                              community by joining us on Slack and Github.
#                              Join our discourse forum to keep up with the latest announcements, troubleshoot with
#                              the community, or show off something you have built with Marqo!
# INFO:root:gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [02/03/24 05:58:18] INFO     ToolkitTask 85c4c6c745074a3ba29d45bcdb16432f
#                              Output: Marqo is an end-to-end vector search engine that handles vector generation,
#                              storage, and retrieval through a single API. It includes input pre-processing, machine
#                              learning inference, and storage out of the box. Marqo can be run on a laptop using a
#                              Docker image or scaled up to dozens of GPU inference nodes in the cloud for low
#                              latency searches against multi-terabyte indexes.
#
#                              Marqo supports deep-learning models like CLIP for extracting semantic meaning from
#                              images and allows for seamless searching of any combination of text and images. It
#                              also supports the combination of text and images into a single vector. With Marqo,
#                              there's no need to calculate vectors yourself. You can select the model you want to
#                              use and pass the text and/or image URLs directly to the API.
#
#                              Marqo supports over 100 languages and provides access to state-of-the-art multilingual
#                              models. It offers a feature-rich developer experience, allowing for multimodal vector
#                              search without sacrificing features like filtering and highlighting. It can handle
#                              image-to-image, image-to-text, and text-to-image searches.
#
#                              Marqo supports weighted queries, score modifiers, and the addition of extra context to
#                              queries by providing vectors directly. It also supports bulk operations for improved
#                              throughput, is horizontally scalable, and provides search highlighting functionality.
#                              Marqo offers a powerful query DSL (Domain Specific Language), which can be applied as
#                              a prefilter ahead of approximate k-NN search.
#
#                              Marqo encourages community involvement through its Slack and Github platforms and also
#                              has a discourse forum for announcements, troubleshooting, and showcasing projects
#                              built with Marqo.
#
#                              For more information, you can visit the [Marqo website](https://www.marqo.ai/).
# Assistant: Marqo is an end-to-end vector search engine that handles vector generation, storage, and retrieval through a single API. It includes input pre-processing, machine learning inference, and storage out of the box. Marqo can be run on a laptop using a Docker image or scaled up to dozens of GPU inference nodes in the cloud for low latency searches against multi-terabyte indexes.
#
# Marqo supports deep-learning models like CLIP for extracting semantic meaning from images and allows for seamless searching of any combination of text and images. It also supports the combination of text and images into a single vector. With Marqo, there's no need to calculate vectors yourself. You can select the model you want to use and pass the text and/or image URLs directly to the API.
#
# Marqo supports over 100 languages and provides access to state-of-the-art multilingual models. It offers a feature-rich developer experience, allowing for multimodal vector search without sacrificing features like filtering and highlighting. It can handle image-to-image, image-to-text, and text-to-image searches.
#
# Marqo supports weighted queries, score modifiers, and the addition of extra context to queries by providing vectors directly. It also supports bulk operations for improved throughput, is horizontally scalable, and provides search highlighting functionality. Marqo offers a powerful query DSL (Domain Specific Language), which can be applied as a prefilter ahead of approximate k-NN search.
#
# Marqo encourages community involvement through its Slack and Github platforms and also has a discourse forum for announcements, troubleshooting, and showcasing projects built with Marqo.
#
# For more information, you can visit the [Marqo website](https://www.marqo.ai/).
# Thinking...
# [02/03/24 06:00:52] INFO     ToolkitTask 85c4c6c745074a3ba29d45bcdb16432f
#                              Input:
# INFO:root:gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [02/03/24 06:00:56] INFO     Subtask ee977733dffe4e668d75ad561947a192
#                              Thought: I need to scrape the content of the website to provide detailed information
#                              about Marqo.
#                              Action: {
#                                "name": "WebScraper",
#                                "path": "get_content",
#                                "input": {
#                                  "values": {
#                                    "url": "https://www.marqo.ai/"
#                                  }
#                                }
#                              }
#                     INFO     Subtask ee977733dffe4e668d75ad561947a192
#                              Response: Marqo is more than a vector database, it's an end-to-end vector search
#                              engine. Vector generation, storage and retrieval are handled out of the box through a
#                              single API. No need to bring your own embeddings.
#                              With Marqo, input pre-processing, machine learning inference, and storage are all
#                              included out of the box.
#                              Run Marqo in a docker image on your laptop or scale it up to dozens of GPU inference
#                              nodes in the cloud. Marqo can be scaled to provide low latency searches against
#                              multi-terabyte indexes.
#                              Marqo helps you configure deep-learning models like CLIP to pull semantic meaning from
#                              images. You can seamlessly search any combination of text and images and even combine
#                              text and images into a single vector.
#                              Marqo has you covered from inference to storage. With Marqo you don't need to
#                              calculate the vectors yourself, simply select the model you want to use and pass the
#                              text and/or image URLs directly to the API.
#                              Search in over 100 languages. Marqo provides access to state of the art multilingual
#                              models. Expand your search to new localities with zero manual language configuration
#                              changes.
#                              Marqo provides a feature rich developer experience - it lets you perform multimodal
#                              vector search without having to sacrifice on features like filtering and highlighting.
#                              Marqo can be used with text and/or image data. Multimodal indexes seamlessly handle
#                              image-to-image, image-to-text and text-to-image search.
#                              Marqo supports weighted queries which can combine multiple text and image queries
#                              together. Negative weights can be added to query terms to push certain items out of
#                              your result set.
#                              Marqo supports score modifiers, numeric fields in your documents can be used to
#                              manipulate the score and influence the ranking of results.
#                              Additional context can be added to queries by providing vectors directly, this helps
#                              tailor results without the overhead of additional inference.
#                              Import open source models from Hugging Face, bring your own, or load private models
#                              from AWS S3 or Hugging Face using authentication.
#                              Parts of Marqo's API support bulk operations to improve throughput. These bulk
#                              operations enable use cases such as bulk changes to multiple indexes or coalescing of
#                              queries.
#                              Marqo is horizontally scalable and can be run at million document scale whilst
#                              maintaining lightning-fast search times.
#                              Marqo provides search highlighting functionality which allows you to transparently
#                              understand where and why a match occurred.
#                              Marqo offers a powerful query DSL (Domain Specific Language), which can be applied as
#                              a prefilter ahead of approximate k-NN search.
#                              Get involved with building the future of Marqo or access support from Marqo's vast
#                              community by joining us on Slack and Github.
#                              Join our discourse forum to keep up with the latest announcements, troubleshoot with
#                              the community, or show off something you have built with Marqo!
# INFO:root:gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# WARNING:root:<RetryCallState 140355487045200: attempt #1; slept for 0.0; last result: failed (KeyboardInterrupt )>
# <RetryCallState 140355487045200: attempt #1; slept for 0.0; last result: failed (KeyboardInterrupt )>
# INFO:root:gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:openai._base_client:Retrying request to /chat/completions in 3.000000 seconds
# Retrying request to /chat/completions in 3.000000 seconds
